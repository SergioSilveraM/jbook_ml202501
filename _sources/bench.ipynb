# %% [markdown]
# # ***BenchMark***

# %% [markdown]
# Aquí va la comparación de los modelos

# %% [markdown]
# ## ***Train Metrics***

# %%
import pandas as pd
pd.options.display.float_format = '{:.2f}'.format
from reporte_metricas import cargar_reportes

df = cargar_reportes("./Metrics/Train_Metrics.csv")

df_filtrado = df[df["Clase"].isin(["macro avg"])].sort_values(by="f1-score", ascending=False).reset_index(drop=True)
display(df_filtrado)
# Out:
# 📊 Reportes cargados correctamente: ['CART' 'CART_Balanced' 'CART_Balanced_ADASYN' 'KNN Model'
#  'KNN Model_Balanced' 'LGBM Model' 'LGBM Model Balanced' 'MLP'
#  'MLP Balanced' 'RF Model' 'RF Model Balanced' 'SVC Model' 'TAB NET Model'
#  'TAB NET Balanced' 'XG-Boost' 'XG-Boost Balanced']
#                   Modelo      Clase  precision  recall  f1-score  support
# 0               XG-Boost  macro avg       0.85    0.80      0.82  4767.00
# 1      XG-Boost Balanced  macro avg       0.82    0.80      0.81  4767.00
# 2             LGBM Model  macro avg       0.85    0.78      0.81  4767.00
# 3    LGBM Model Balanced  macro avg       0.78    0.80      0.79  4767.00
# 4               RF Model  macro avg       0.77    0.80      0.79  4767.00
# 5       TAB NET Balanced  macro avg       0.78    0.78      0.78  4767.00
# 6      RF Model Balanced  macro avg       0.77    0.78      0.78  4767.00
# 7              SVC Model  macro avg       0.81    0.74      0.77  4767.00
# ...

# %% [markdown]
# ## ***Test Metrics***

# %%
from reporte_metricas import cargar_reportes

df = cargar_reportes("./Metrics/Test_Metrics.csv")

df_filtrado = df[df["Clase"].isin(["macro avg"])].sort_values(by="f1-score", ascending=False).reset_index(drop=True)
display(df_filtrado)
# Out:
# 📊 Reportes cargados correctamente: ['CART' 'KNN Model' 'LGBM Model' 'MLP' 'RF Model' 'SVC Model'
#  'TAB NET Model' 'XG-Boost' 'CART_Balanced' 'CART_Balanced_ADASYN'
#  'KNN Model_Balanced' 'LGBM Model Balanced' 'MLP Balanced'
#  'RF Model Balanced' 'TAB NET Balanced' 'XG-Boost Balanced']
#                   Modelo      Clase  precision  recall  f1-score  support
# 0               XG-Boost  macro avg       0.85    0.80      0.82  4767.00
# 1      XG-Boost Balanced  macro avg       0.82    0.80      0.81  4767.00
# 2      XG-Boost Balanced  macro avg       0.82    0.80      0.81  4767.00
# 3             LGBM Model  macro avg       0.84    0.77      0.80  4767.00
# 4    LGBM Model Balanced  macro avg       0.78    0.79      0.79  4767.00
# 5    LGBM Model Balanced  macro avg       0.78    0.79      0.79  4767.00
# 6               RF Model  macro avg       0.77    0.80      0.79  4767.00
# 7              SVC Model  macro avg       0.81    0.75      0.78  4767.00
# ...

# %% [markdown]
# ## ***Modelo Final***

# %%
from reporte_metricas import cargar_reportes

df = cargar_reportes("./Metrics/Test_Metrics.csv")

df_filtrado = df[df["Modelo"].isin(["XG-Boost"])].reset_index(drop=True)
display(df_filtrado)
# Out:
# 📊 Reportes cargados correctamente: ['CART' 'KNN Model' 'LGBM Model' 'MLP' 'RF Model' 'SVC Model'
#  'TAB NET Model' 'XG-Boost' 'CART_Balanced' 'CART_Balanced_ADASYN'
#  'KNN Model_Balanced' 'LGBM Model Balanced' 'MLP Balanced'
#  'RF Model Balanced' 'TAB NET Balanced' 'XG-Boost Balanced']
#      Modelo         Clase  precision  recall  f1-score  support
# 0  XG-Boost             0       0.91    0.97      0.94  3211.00
# 1  XG-Boost             1       0.80    0.70      0.74   970.00
# 2  XG-Boost             2       0.83    0.72      0.77   586.00
# 3  XG-Boost      accuracy       0.88    0.88      0.88     0.88
# 4  XG-Boost     macro avg       0.85    0.80      0.82  4767.00
# 5  XG-Boost  weighted avg       0.88    0.88      0.88  4767.00
